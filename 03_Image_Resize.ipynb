# %% [markdown]
# # Image Resize 하기

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img_path = "./test.jpg"
img = cv2.imread(img_path,1)
height, width = img.shape[:2]
down_img = cv2.resize(img,(height//2,width//2))
cv2_imshow(down_img)
# Out:
# <PIL.Image.Image image mode=RGB size=179x320 at 0x7FF8A297E438>

# %%
up_img = cv2.resize(img, (height*2, width*2))
cv2_imshow(up_img)
# Out:
# <PIL.Image.Image image mode=RGB size=718x1280 at 0x7FF8A28D8860>

# %%
img_list = [] 
for i in range(100):
    img_list.append(cv2.resize(img,(height+i,width+i)))
cv2_imshow(img_list[0])
cv2_imshow(img_list[-1])
# Out:
# <PIL.Image.Image image mode=RGB size=359x640 at 0x7FF8A28E5160>
# <PIL.Image.Image image mode=RGB size=458x739 at 0x7FF8A28E5080>
